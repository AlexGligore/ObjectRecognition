# %%
# requirements
import sys
# !{sys.executable} -m pip install numpy
# !{sys.executable} -m pip install opencv-python
# !{sys.executable} -m pip install scipy
# !{sys.executable} -m pip install keras
# !{sys.executable} -m pip install tensorflow
# Out:
# Requirement already satisfied: numpy in c:\users\alex\appdata\roaming\python\python37\site-packages (1.19.5)
# Requirement already satisfied: opencv-python in c:\programdata\anaconda3\lib\site-packages (4.5.2.54)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\alex\appdata\roaming\python\python37\site-packages (from opencv-python) (1.19.5)
# Requirement already satisfied: scipy in c:\programdata\anaconda3\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in c:\users\alex\appdata\roaming\python\python37\site-packages (from scipy) (1.19.5)
# Requirement already satisfied: keras in c:\programdata\anaconda3\lib\site-packages (2.4.3)
# Requirement already satisfied: scipy>=0.14 in c:\programdata\anaconda3\lib\site-packages (from keras) (1.4.1)
# Requirement already satisfied: h5py in c:\users\alex\appdata\roaming\python\python37\site-packages (from keras) (3.1.0)
# Requirement already satisfied: numpy>=1.9.1 in c:\users\alex\appdata\roaming\python\python37\site-packages (from keras) (1.19.5)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from keras) (5.3)
# Requirement already satisfied: cached-property; python_version < "3.8" in c:\users\alex\appdata\roaming\python\python37\site-packages (from h5py->keras) (1.5.2)
# Requirement already satisfied: tensorflow in c:\users\alex\appdata\roaming\python\python37\site-packages (2.5.0)
# Requirement already satisfied: tensorflow-estimator<2.6.0,>=2.5.0rc0 in c:\programdata\anaconda3\lib\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: protobuf>=3.9.2 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (3.17.3)
# Requirement already satisfied: tensorboard~=2.5 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: numpy~=1.19.2 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.19.5)
# Requirement already satisfied: absl-py~=0.10 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (0.13.0)
# Requirement already satisfied: opt-einsum~=3.3.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (3.3.0)
# Requirement already satisfied: gast==0.4.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (0.4.0)
# Requirement already satisfied: grpcio~=1.34.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.34.1)
# Requirement already satisfied: termcolor~=1.1.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.1.0)
# Requirement already satisfied: h5py~=3.1.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: google-pasta~=0.2 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: six~=1.15.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.15.0)
# Requirement already satisfied: typing-extensions~=3.7.4 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (3.7.4.3)
# Requirement already satisfied: keras-preprocessing~=1.1.2 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.1.2)
# Requirement already satisfied: wrapt~=1.12.1 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.12.1)
# Requirement already satisfied: wheel~=0.35 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (0.36.2)
# Requirement already satisfied: flatbuffers~=1.12.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.12)
# Requirement already satisfied: keras-nightly~=2.5.0.dev in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (2.5.0.dev2021032900)
# Requirement already satisfied: astunparse~=1.6.3 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorboard~=2.5->tensorflow) (0.4.4)
# Requirement already satisfied: google-auth<2,>=1.6.3 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorboard~=2.5->tensorflow) (1.31.0)
# Requirement already satisfied: setuptools>=41.0.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (45.2.0.post20200210)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorboard~=2.5->tensorflow) (3.3.4)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (2.22.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorboard~=2.5->tensorflow) (1.8.0)
# Requirement already satisfied: werkzeug>=0.11.15 in c:\programdata\anaconda3\lib\site-packages (from tensorboard~=2.5->tensorflow) (1.0.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from tensorboard~=2.5->tensorflow) (0.6.1)
# Requirement already satisfied: cached-property; python_version < "3.8" in c:\users\alex\appdata\roaming\python\python37\site-packages (from h5py~=3.1.0->tensorflow) (1.5.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (1.3.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.2.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\alex\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in c:\users\alex\appdata\roaming\python\python37\site-packages (from google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (4.7.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in c:\programdata\anaconda3\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.5->tensorflow) (1.5.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (1.25.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (3.0.4)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2.8)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard~=2.5->tensorflow) (2019.11.28)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\alex\appdata\roaming\python\python37\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard~=2.5->tensorflow) (3.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\alex\appdata\roaming\python\python37\site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard~=2.5->tensorflow) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in c:\programdata\anaconda3\lib\site-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard~=2.5->tensorflow) (2.2.0)

# %%
# import modules
from scipy import ndimage
import skimage
import numpy as np
import random
import cv2
import copy
import os

# %%
# define data augmentation parameters
augmentation_parameters = {
    "grayscale": False,
    "flip": True,
    "rotate": True,
    "shift": True,
    "noise": True,
    "blur": True,
    "rotation_values": {
        "random_angle": True,
        "specific_angle": None
    },
    "shifting_values": {
        "min_shift": 1,
        "max_shift": 25
    },
    "noise_values": {
        "mean": 0,
        "var": 0.01
    },
    "blur_values": {
        "sigma": 1
    }
}

# %%
# augmentation operations

# img grayscale
def img_grayscale(img):
    return cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# img flip
def img_flip(img):
    flip = {
        0: np.flip,
        1: np.flipud,
        2: np.fliplr
    }

    operation = random.randint(0, 2)
    flipped_img = flip[operation](img)
    return flipped_img

# img rotation
def img_rotate(img):
    random_angle = augmentation_parameters["rotation_values"]["random_angle"]
    specific_angle = augmentation_parameters["rotation_values"]["specific_angle"]

    if random_angle is False and specific_angle is None:
        rotation = {
            0: cv2.ROTATE_90_CLOCKWISE,
            1: cv2.ROTATE_90_COUNTERCLOCKWISE,
            2: cv2.ROTATE_180
        }
        operation = random.randint(0, 2)
        rotated_img = cv2.rotate(img, rotation[operation])
    elif random_angle is True:
        angle = random.randint(0, 360)
        rotated_img = ndimage.rotate(img, angle)
    elif specific_angle is not None:
        angle = int(specific_angle)
        rotated_img = ndimage.rotate(img, angle)
    else:
        print("No rotation could be done to the image, please check the parameters")
        return img

    return rotated_img

# img shifting
def img_shift(img):
    min_shift = augmentation_parameters["shifting_values"]["min_shift"]
    max_shift = augmentation_parameters["shifting_values"]["max_shift"]

    # RGB img
    if len(img.shape) == 3:
        shift = [random.uniform(min_shift, max_shift), random.uniform(min_shift, max_shift), 0]
        shifted_img = ndimage.shift(img, shift)
    # Grayscale img
    else:
        shift = [random.uniform(min_shift, max_shift), random.uniform(min_shift, max_shift)]
        shifted_img = ndimage.shift(img, shift)

    return shifted_img

# adding noise
def img_noise(img):
    mean = augmentation_parameters["noise_values"]["mean"]
    var = augmentation_parameters["noise_values"]["var"]

    modes = ['gaussian', 'localvar', 'poisson', 'salt', 'pepper', 's&p', 'speckle']
    mode = modes[random.randint(0, len(modes) - 1)]

    if mode == 'gaussian' or mode == 'speckle':
        noisy_img = skimage.util.random_noise(img, mean=mean, var=var)
    else:
        noisy_img = skimage.util.random_noise(img)

    return (255 * noisy_img).astype(np.uint8)

# blurring
def img_blur(img):
    sigma = augmentation_parameters["blur_values"]["sigma"]

    blurring_value = random.uniform(0, sigma)
    blurred_img = ndimage.gaussian_filter(img, sigma=blurring_value)
    return blurred_img

# %%
# dataset generation from one image

# generate available operations map
available_ops = []

if augmentation_parameters['grayscale'] is True:
    available_ops.append(img_grayscale)
if augmentation_parameters['flip'] is True:
    available_ops.append(img_flip)
if augmentation_parameters['rotate'] is True:
    available_ops.append(img_rotate)
if augmentation_parameters['shift'] is True:
    available_ops.append(img_shift)
if augmentation_parameters['noise'] is True:
    available_ops.append(img_noise)
if augmentation_parameters['blur'] is True:
    available_ops.append(img_blur)

if len(available_ops) == 0:
    raise ValueError("No operations allowed, please check config file for augmentation ops.")

def generate_dataset(img, dataset_size, nr_op, image_prefix=None, save=False, save_path=None):
    dataset = []
    for i in range(dataset_size):
        augmented_img = copy.copy(img)
        for j in range(nr_op):
            operation = random.randint(0, len(available_ops) - 1)
            augmented_img = available_ops[operation](augmented_img)

        if save is True:
            if image_prefix is not None:
                img_name = save_path + str(image_prefix) + '_augmented_' + str(i) + '.jpg'
            else:
                img_name = save_path + 'augmented_' + str(i) + '.jpg'
            cv2.imwrite(img_name, augmented_img)

        dataset.append(augmented_img)

    return dataset

# %%
# read images from folder
def read_images(data_folder, img_format):
    # read the images

    image_data = {}
    for img in os.listdir(data_folder):
        read_img_format = os.path.splitext(img)[1]
        if read_img_format in img_format:
            image_data[img] = cv2.imread(data_folder + img, cv2.IMREAD_COLOR)
    print("Image reading complete.")
    return image_data

# %%
# image resizing
def resize_images(image_data, desired_image_size, save=False, save_path=None):

    resized_images = {}
    for img in image_data:
        resized_images[img] = cv2.resize(image_data[img], desired_image_size, interpolation=cv2.INTER_AREA)

    # save resized images
    if save is True:
        if os.path.exists(save_path) is False:
            os.makedirs(save_path, exist_ok=True)

        for img in resized_images:
            path = save_path + img
            cv2.imwrite(path, resized_images[img])
    print("Image resizing complete.")

    return resized_images

# %%
# augment a image into a dataset
def augment_dataset(image_data, dataset_size=50, nr_op=5, save=False, save_path=None):
    # augment a dataset
    complete_dataset = {}
    for img in image_data:
        img_name = os.path.splitext(img)[0]
        if save is True:
            temp_save_path = save_path + img_name + '/'
            if save is True and os.path.exists(temp_save_path) is False:
                os.makedirs(temp_save_path, exist_ok=True)

        temp_dataset = generate_dataset(image_data[img], dataset_size, nr_op, image_prefix=img_name, save=save, save_path=temp_save_path)
        complete_dataset[img_name] = temp_dataset

    if save is True:
        print("Data augmentation completed successfully. Results can be found in {0}".format(save_path))
        return complete_dataset
    else:
        print("Data augmentation completed successfully.")
        return complete_dataset

# %%
# load a image and generate some data
images_folder = './data/originals/'
images_format = '.jpg'
images_data = read_images(images_folder, images_format)
# Out:
# Image reading complete.

# %%
# resize the images to be sure that they are in the correct format
resized_images_save_path = './data/original_resized/'
desired_size = (128, 128)
resized_images = resize_images(images_data, desired_size, True, resized_images_save_path)
# Out:
# Image resizing complete.

# %%
# augment images into datasets
# define parameters
dataset_size = 200  # images generated / input image
nr_op = 5  # nr. of operations done per image
augmented_dataset_save_path = './data/augmented_dataset/'
augmented_dataset = augment_dataset(resized_images, dataset_size, nr_op, True, augmented_dataset_save_path)

# do a final resize to be sure the images are the same size
resized_imgs = {}
for img_type in augmented_dataset.keys():
    resized_imgs[img_type] = []
    for img in augmented_dataset[img_type]:
        resized_img = cv2.resize(img, desired_size, interpolation=cv2.INTER_AREA)
        resized_imgs[img_type].append(resized_img)

augmented_dataset = resized_imgs
# Out:
# Data augmentation completed successfully. Results can be found in ./data/augmented_dataset/

# %%
from keras.models import Sequential
from keras.layers import Conv2D, Dense, Flatten, MaxPooling2D, InputLayer, Dropout
from keras.utils.np_utils import to_categorical

# create the architecture of a simple model
def simple_classifier(classes_nr, input_shape=(128, 128, 3)):

    model = Sequential()

    model.add(Conv2D(filters=32, kernel_size=3, strides=3, activation='relu', input_shape=input_shape))
    model.add(Conv2D(filters=32, kernel_size=3, strides=3, activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))

    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(classes_nr, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

    return model

# %%
# in case you have a graphics card installed
os.environ["CUDA_VISIBLE_DEVICES"] = "-1"

# train the model
# create train data
labels = {}
label_index = 0
for key in augmented_dataset.keys():
    labels[key] = label_index
    label_index += 1

classes_nr = len(list(labels.keys()))

train_data = []
label_data = []

for key, value in augmented_dataset.items():
    label_value = labels[key]
    for img in value:
        train_data.append(img)
        label_data.append(label_value)

train_data = np.asarray(train_data).astype(np.float32)
label_data = np.asarray(label_data).astype(np.float32)
label_data = to_categorical(label_data, classes_nr)

model = simple_classifier(classes_nr)
model.fit(train_data, label_data, batch_size=4, epochs=100, verbose=1, shuffle=True)
model.save('test_model.h5')
# Out:
# Epoch 1/100
# 250/250 [==============================] - 10s 3ms/step - loss: 30.2416 - accuracy: 0.2031
# Epoch 2/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.6704 - accuracy: 0.2890
# Epoch 3/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.4997 - accuracy: 0.3237
# Epoch 4/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.4681 - accuracy: 0.3712
# Epoch 5/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.3090 - accuracy: 0.4422
# Epoch 6/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.2246 - accuracy: 0.5199
# Epoch 7/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.1623 - accuracy: 0.5220
# Epoch 8/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.0730 - accuracy: 0.5849
# Epoch 9/100
# 250/250 [==============================] - 1s 3ms/step - loss: 1.0830 - accuracy: 0.5996
# Epoch 10/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8868 - accuracy: 0.6639
# Epoch 11/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.9915 - accuracy: 0.6424
# Epoch 12/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8733 - accuracy: 0.6720
# Epoch 13/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8165 - accuracy: 0.6904
# Epoch 14/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7632 - accuracy: 0.6763
# Epoch 15/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7654 - accuracy: 0.7226
# Epoch 16/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6589 - accuracy: 0.7717
# Epoch 17/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8231 - accuracy: 0.6498
# Epoch 18/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7013 - accuracy: 0.7265
# Epoch 19/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7859 - accuracy: 0.7118
# Epoch 20/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5569 - accuracy: 0.7725
# Epoch 21/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5702 - accuracy: 0.7666
# Epoch 22/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5904 - accuracy: 0.7765
# Epoch 23/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.6624 - accuracy: 0.7489
# Epoch 24/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5868 - accuracy: 0.7526
# Epoch 25/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.8132 - accuracy: 0.7737
# Epoch 26/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4791 - accuracy: 0.7961
# Epoch 27/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5451 - accuracy: 0.8005
# Epoch 28/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4471 - accuracy: 0.8155
# Epoch 29/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4449 - accuracy: 0.8263
# Epoch 30/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5321 - accuracy: 0.8188
# Epoch 31/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4169 - accuracy: 0.8385
# Epoch 32/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4160 - accuracy: 0.8564
# Epoch 33/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3556 - accuracy: 0.8594
# Epoch 34/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4490 - accuracy: 0.8448
# Epoch 35/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4084 - accuracy: 0.8407
# Epoch 36/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4485 - accuracy: 0.8558
# Epoch 37/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4638 - accuracy: 0.8303
# Epoch 38/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3377 - accuracy: 0.8548
# Epoch 39/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3171 - accuracy: 0.8877
# Epoch 40/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3064 - accuracy: 0.8651
# Epoch 41/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3711 - accuracy: 0.8732
# Epoch 42/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4234 - accuracy: 0.8481
# Epoch 43/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3790 - accuracy: 0.8696
# Epoch 44/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.4241 - accuracy: 0.8558
# Epoch 45/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3962 - accuracy: 0.8592
# Epoch 46/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3996 - accuracy: 0.8671
# Epoch 47/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3584 - accuracy: 0.8637
# Epoch 48/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.5604 - accuracy: 0.8408
# Epoch 49/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3032 - accuracy: 0.8894
# Epoch 50/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2631 - accuracy: 0.8998
# Epoch 51/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3539 - accuracy: 0.8594
# Epoch 52/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2808 - accuracy: 0.8872
# Epoch 53/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2420 - accuracy: 0.9062
# Epoch 54/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3005 - accuracy: 0.9016
# Epoch 55/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3044 - accuracy: 0.8940
# Epoch 56/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2571 - accuracy: 0.9028
# Epoch 57/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3508 - accuracy: 0.8750: 0s - loss: 0.3497 - accuracy: 0.
# Epoch 58/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2569 - accuracy: 0.9174
# Epoch 59/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2632 - accuracy: 0.9064
# Epoch 60/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3224 - accuracy: 0.8939
# Epoch 61/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2629 - accuracy: 0.8994
# Epoch 62/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3423 - accuracy: 0.8789
# Epoch 63/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3015 - accuracy: 0.9057
# Epoch 64/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2173 - accuracy: 0.9202
# Epoch 65/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3186 - accuracy: 0.9030
# Epoch 66/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2221 - accuracy: 0.9222
# Epoch 67/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2261 - accuracy: 0.9268
# Epoch 68/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7753 - accuracy: 0.8278
# Epoch 69/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2654 - accuracy: 0.9063
# Epoch 70/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1725 - accuracy: 0.9390
# Epoch 71/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2783 - accuracy: 0.9091
# Epoch 72/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3786 - accuracy: 0.8995
# Epoch 73/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2559 - accuracy: 0.9074
# Epoch 74/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2114 - accuracy: 0.9318
# Epoch 75/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2011 - accuracy: 0.9288
# Epoch 76/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1887 - accuracy: 0.9424
# Epoch 77/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2235 - accuracy: 0.9364
# Epoch 78/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3241 - accuracy: 0.9060
# Epoch 79/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3621 - accuracy: 0.9103
# Epoch 80/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3010 - accuracy: 0.9087
# Epoch 81/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1839 - accuracy: 0.9322
# Epoch 82/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2602 - accuracy: 0.9018
# Epoch 83/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2191 - accuracy: 0.9384
# Epoch 84/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1635 - accuracy: 0.9384
# Epoch 85/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1948 - accuracy: 0.9246
# Epoch 86/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1929 - accuracy: 0.9344
# Epoch 87/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2186 - accuracy: 0.9353
# Epoch 88/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2407 - accuracy: 0.9163
# Epoch 89/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3439 - accuracy: 0.9232
# Epoch 90/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2317 - accuracy: 0.9193
# Epoch 91/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1864 - accuracy: 0.9615
# Epoch 92/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2808 - accuracy: 0.9249
# Epoch 93/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.7945 - accuracy: 0.8719
# Epoch 94/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1601 - accuracy: 0.9490
# Epoch 95/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1780 - accuracy: 0.9518
# Epoch 96/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3027 - accuracy: 0.9085
# Epoch 97/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2087 - accuracy: 0.9391
# Epoch 98/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.3527 - accuracy: 0.8902
# Epoch 99/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.2032 - accuracy: 0.9429
# Epoch 100/100
# 250/250 [==============================] - 1s 3ms/step - loss: 0.1875 - accuracy: 0.9406
